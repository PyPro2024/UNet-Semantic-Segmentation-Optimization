# %% [markdown]
# ***Tutorial***
#
#
# ---

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import cv2
#                           create synthetic images and masks
def create_sample_data(img_size=128, num_samples =100):
  images =[]
  masks = []
  for _ in range(num_samples):
    img =np.zeros((img_size, img_size, 3), dtype=np.uint8)
    mask = np.zeros((img_size,img_size,1), dtype=np.uint8)
    # Add a random rectangle
    x1, y1, x2, y2 = np.random.randint(0, img_size // 2, 4)
    x2, y2 = x2 + img_size // 2, y2 + img_size // 2
    img = cv2.rectangle(img, (x1, y1), (x2, y2), (255, 255, 255),-1)
    mask = cv2.rectangle(mask, (x1, y1), (x2, y2), (1),-1)
    images.append(img)
    masks.append(mask)
  return np.array(images) /255.0, np.array(masks)
#generate synthetic data
images,masks = create_sample_data()

#                            Defin U-Net Model
def unet(input_size=(128, 128, 3)):
    inputs = layers.Input(input_size)
    # Encoder
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2))(c1)

    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2))(c2)

    #Bottleneck
    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c3)

    #Decoder
    u1 = layers.UpSampling2D((2,2))(c3)
    u1 = layers.concatenate([u1, c2])
    c4 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(u1)
    c4 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c4)

    u2 = layers.UpSampling2D((2,2))(c4)
    u2 = layers.concatenate([u2, c1])
    c5 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(u2)
    c5 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c5)

    outputs = layers.Conv2D(1, (1,1), activation='sigmoid')(c5)

    return Model(inputs, outputs)

# Build the model
model = unet()
model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

#                              Train the model
# Split data into training and validation sets
train_images, val_images = images[:80], images[80:]
train_masks, val_masks = masks[:80], masks[80:]

# Train the U-Net model
history = model.fit(
    train_images, train_masks,
    validation_data=(val_images, val_masks),
    batch_size=8,
    epochs=20
)

#                            Evaluate & Visualize Results
# Evaluate the model on validation data
loss, accuracy = model.evaluate(val_images, val_masks)
print(f"Validation Loss: {loss}, Validation Accuracy: {accuracy}")

#                            Visualization
# Predict on a few validation samples
pred_masks = model.predict(val_images)

# Plot the results
def plot_sample(image, true_mask, pred_mask):
  plt.figure(figsize=(10,4))

  plt.subplot(1,3,1)
  plt.title('Input Image')
  plt.imshow(image)

  plt.subplot(1,3,2)
  plt.title('True Mask')
  plt.imshow(true_mask.squeeze(), cmap='gray')

  plt.subplot(1,3,3)
  plt.title('Predicted Mask')
  plt.imshow((pred_mask.squeeze() > 0.5).astype(np.uint8),cmap='gray')

# show a sample result
for i in range(3):
  plot_sample(val_images[i], val_masks[i], pred_masks[i])
  plt.show()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │      1,792 │ input_layer[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     36,928 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# TASK2:
#
# ---
#
#
# I used github segmentation images. and applied the same code of tutorial on it. The results showed
# Validation Loss: 0.5106567144393921, Validation Accuracy: 0.7668134570121765
#
# By increasing one layer in both encoder & decoder the results got better with
# Validation Loss: 0.42889919877052307, Validation Accuracy: 0.8167358636856079
#
# When I chnaged the learning rate to 0.001 the results were not really good as compared to previous results as accuracy dropped and loss increase
# Validation Loss: 0.4723464846611023, Validation Accuracy: 0.7846839427947998
#
# At learning rate .00001 the results got worse then 1st time
# Validation Loss: 0.5145471692085266, Validation Accuracy: 0.7530477046966553

# %%
# !git clone https://github.com/VikramShenoy97/Human-Segmentation-Dataset.git
# Out:
# fatal: destination path 'Human-Segmentation-Dataset' already exists and is not an empty directory.

# %% [markdown]
# ***Results without changing the layers***

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import os
from sklearn.model_selection import train_test_split

# Creating path of folder for segmentation data
dataset_root_folder = 'Human-Segmentation-Dataset'
img_folder = os.path.join(dataset_root_folder, 'Training_Images')
mask_folder = os.path.join(dataset_root_folder, 'Ground_Truth')

# Add diagnostic checks
print(f"Current working directory: {os.getcwd()}")
if not os.path.exists(dataset_root_folder):
    print(f"Error: The dataset root directory '{dataset_root_folder}' was not found.")
    print("Please ensure the 'git clone' command in the previous cell was executed successfully and the Colab runtime has not been restarted.")
    # This line will still cause FileNotFoundError later if execution continues, but provides context.
elif not os.path.exists(img_folder):
    print(f"Error: The image training directory '{img_folder}' was not found inside '{dataset_root_folder}'.")
    print("Please check the structure of the cloned repository and ensure the 'Training_Images' folder exists.")

image_files = sorted(os.listdir(img_folder))
mask_files = sorted(os.listdir(mask_folder))

images = []
masks = []

for img_file, mask_file in zip(image_files, mask_files):
    try:
        # Read and Resize Image
        img_path = os.path.join(img_folder, img_file)
        img = cv2.imread(img_path)
        img = cv2.resize(img, (128, 128))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Read and Resize Mask
        mask_path = os.path.join(mask_folder, mask_file)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (128, 128))

        # Normalize and Append
        images.append(img / 255.0)
        masks.append(np.expand_dims(mask, axis=-1) / 255.0)
    except Exception as e:
        print(f"Error loading {img_file}: {e}")

images = np.array(images)
masks = np.array(masks)
print(f"Loaded {len(images)} images and masks")

#                            Defin U-Net Model
def unet(input_size=(128, 128, 3)):
    inputs = layers.Input(input_size)
    # Encoder
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2))(c1)

    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2))(c2)

    #Bottleneck
    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c3)

    #Decoder
    u1 = layers.UpSampling2D((2,2))(c3)
    u1 = layers.concatenate([u1, c2])
    c4 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(u1)
    c4 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c4)

    u2 = layers.UpSampling2D((2,2))(c4)
    u2 = layers.concatenate([u2, c1])
    c5 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(u2)
    c5 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c5)

    outputs = layers.Conv2D(1, (1,1), activation='sigmoid')(c5)

    return Model(inputs, outputs)

# Build the model
model = unet()
model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

#                             Train the model
# Split data into training and validation sets
train_images, val_images = images[:80], images[80:]
train_masks, val_masks = masks[:80], masks[80:]

# Train the U-Net model
history = model.fit(
    train_images, train_masks,
    validation_data=(val_images, val_masks),
    batch_size=8,
    epochs=20
)

#                            Evaluate & Visualize Results
# Evaluate the model on validation data
loss, accuracy = model.evaluate(val_images, val_masks)
print(f"Validation Loss: {loss}, Validation Accuracy: {accuracy}")

#                            Visualization
# Predict on a few validation samples
pred_masks = model.predict(val_images)

# Plot the results
def plot_sample(image, true_mask, pred_mask):
  plt.figure(figsize=(10,4))

  plt.subplot(1,3,1)
  plt.title('Input Image')
  plt.imshow(image)

  plt.subplot(1,3,2)
  plt.title('True Mask')
  plt.imshow(true_mask.squeeze(), cmap='gray')

  plt.subplot(1,3,3)
  plt.title('Predicted Mask')
  plt.imshow((pred_mask.squeeze() > 0.5).astype(np.uint8),cmap='gray')

# show a sample result
for i in range(3):
  plot_sample(val_images[i], val_masks[i], pred_masks[i])
  plt.show()
# Out:
# Current working directory: /content
# Error loading .DS_Store: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# Loaded 290 images and masks
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │      1,792 │ input_layer_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# ***Results with increasing the layers***
#
# Increased one layer of both encoder & decoder

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import os
from sklearn.model_selection import train_test_split
# Creating path of folder for segmentation data
dataset_root_folder = 'Human-Segmentation-Dataset'
img_folder = os.path.join(dataset_root_folder, 'Training_Images')
mask_folder = os.path.join(dataset_root_folder, 'Ground_Truth')

print("Loading images and masks")
# Sort files to ensure images align with their correct masks
img_files = sorted(os.listdir(img_folder))
mask_files = sorted(os.listdir(mask_folder))

images = []
masks = []

for img_file, mask_file in zip(img_files, mask_files):
    try:
        # Read Image
        img_path = os.path.join(img_folder, img_file)
        img = cv2.imread(img_path)
        img = cv2.resize(img, (128, 128))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Read Mask
        mask_path = os.path.join(mask_folder, mask_file)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (128, 128))

        # Normalize
        images.append(img / 255.0)
        masks.append(np.expand_dims(mask, axis=-1) / 255.0)
    except Exception as e:
        print(f"Skipping file: {e}")

images = np.array(images)
masks = np.array(masks)
print(f"Data Loaded. Images: {images.shape}, Masks: {masks.shape}")

#                       Define U-Net Model
def unet(input_size=(128, 128, 3)):
    inputs = layers.Input(input_size)
    # Encoder
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2))(c1)

    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2))(c2)

    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2,2))(c3)

    # Bottleneck
    c4 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(c4)

    # Decoder
    u1 = layers.UpSampling2D((2,2))(c4)
    u1 = layers.concatenate([u1, c3])
    c5 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(u1)
    c5 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c5)

    u2 = layers.UpSampling2D((2,2))(c5)
    u2 = layers.concatenate([u2, c2])
    c6 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(u2)
    c6 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c6)

    u3 = layers.UpSampling2D((2,2))(c6)
    u3 = layers.concatenate([u3, c1])
    c7 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(u3)
    c7 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c7)

    outputs = layers.Conv2D(1, (1,1), activation='sigmoid')(c7)

    return Model(inputs, outputs)

# Build the model
model = unet()
model.compile(optimizer=Adam(learning_rate=1e-4), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

#                             Train the model
# Split data into training and validation sets
# Note: Ensure you have at least 81 images loaded for this split to work
train_images, val_images = images[:80], images[80:]
train_masks, val_masks = masks[:80], masks[80:]

# Train the U-Net model
history = model.fit(
    train_images, train_masks,
    validation_data=(val_images, val_masks),
    batch_size=8,
    epochs=20
)

#                            Evaluate & Visualize Results
# Evaluate the model on validation data
loss, accuracy = model.evaluate(val_images, val_masks)
print(f"Validation Loss: {loss}, Validation Accuracy: {accuracy}")

#                            Visualization
# Predict on a few validation samples
pred_masks = model.predict(val_images)

# Plot the results
def plot_sample(image, true_mask, pred_mask):
    plt.figure(figsize=(10,4))

    plt.subplot(1,3,1)
    plt.title('Input Image')
    plt.imshow(image)

    plt.subplot(1,3,2)
    plt.title('True Mask')
    plt.imshow(true_mask.squeeze(), cmap='gray')

    plt.subplot(1,3,3)
    plt.title('Predicted Mask')
    plt.imshow((pred_mask.squeeze() > 0.5).astype(np.uint8),cmap='gray')

# show a sample result
for i in range(3):
    # Check to make sure we actually have validation images to show
    if i < len(val_images):
        plot_sample(val_images[i], val_masks[i], pred_masks[i])
        plt.show()
# Out:
# Loading images and masks
# Skipping file: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# Data Loaded. Images: (290, 128, 128, 3), Masks: (290, 128, 128, 1)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 128, 128,  │      1,792 │ input_layer_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %% [markdown]
# ***Changed learning rate to 0.001***
#
# The results were not really good as compared to previous results
# Validation Loss: 0.4723464846611023, Validation Accuracy: 0.7846839427947998

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import os
from sklearn.model_selection import train_test_split
# Creating path of folder for segmentation data
dataset_root_folder = 'Human-Segmentation-Dataset'
img_folder = os.path.join(dataset_root_folder, 'Training_Images')
mask_folder = os.path.join(dataset_root_folder, 'Ground_Truth')

print("Loading images and masks")
# Sort files to ensure images align with their correct masks
img_files = sorted(os.listdir(img_folder))
mask_files = sorted(os.listdir(mask_folder))

images = []
masks = []

for img_file, mask_file in zip(img_files, mask_files):
    try:
        # Read Image
        img_path = os.path.join(img_folder, img_file)
        img = cv2.imread(img_path)
        img = cv2.resize(img, (128, 128))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Read Mask
        mask_path = os.path.join(mask_folder, mask_file)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (128, 128))

        # Normalize
        images.append(img / 255.0)
        masks.append(np.expand_dims(mask, axis=-1) / 255.0)
    except Exception as e:
        print(f"Skipping file: {e}")

images = np.array(images)
masks = np.array(masks)
print(f"Data Loaded. Images: {images.shape}, Masks: {masks.shape}")

#                       Define U-Net Model
def unet(input_size=(128, 128, 3)):
    inputs = layers.Input(input_size)
    # Encoder
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2))(c1)

    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2))(c2)

    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2,2))(c3)

    # Bottleneck
    c4 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(c4)

    # Decoder
    u1 = layers.UpSampling2D((2,2))(c4)
    u1 = layers.concatenate([u1, c3])
    c5 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(u1)
    c5 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c5)

    u2 = layers.UpSampling2D((2,2))(c5)
    u2 = layers.concatenate([u2, c2])
    c6 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(u2)
    c6 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c6)

    u3 = layers.UpSampling2D((2,2))(c6)
    u3 = layers.concatenate([u3, c1])
    c7 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(u3)
    c7 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c7)

    outputs = layers.Conv2D(1, (1,1), activation='sigmoid')(c7)

    return Model(inputs, outputs)

# Build the model
model = unet()
model.compile(optimizer=Adam(learning_rate=1e-3), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

#                             Train the model
# Split data into training and validation sets
# Note: Ensure you have at least 81 images loaded for this split to work
train_images, val_images = images[:80], images[80:]
train_masks, val_masks = masks[:80], masks[80:]

# Train the U-Net model
history = model.fit(
    train_images, train_masks,
    validation_data=(val_images, val_masks),
    batch_size=8,
    epochs=20
)

#                            Evaluate & Visualize Results
# Evaluate the model on validation data
loss, accuracy = model.evaluate(val_images, val_masks)
print(f"Validation Loss: {loss}, Validation Accuracy: {accuracy}")

#                            Visualization
# Predict on a few validation samples
pred_masks = model.predict(val_images)

# Plot the results
def plot_sample(image, true_mask, pred_mask):
    plt.figure(figsize=(10,4))

    plt.subplot(1,3,1)
    plt.title('Input Image')
    plt.imshow(image)

    plt.subplot(1,3,2)
    plt.title('True Mask')
    plt.imshow(true_mask.squeeze(), cmap='gray')

    plt.subplot(1,3,3)
    plt.title('Predicted Mask')
    plt.imshow((pred_mask.squeeze() > 0.5).astype(np.uint8),cmap='gray')

# show a sample result
for i in range(3):
    # Check to make sure we actually have validation images to show
    if i < len(val_images):
        plot_sample(val_images[i], val_masks[i], pred_masks[i])
        plt.show()
# Out:
# Loading images and masks
# Skipping file: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# Data Loaded. Images: (290, 128, 128, 3), Masks: (290, 128, 128, 1)
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_3       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_37 (Conv2D)  │ (None, 128, 128,  │      1,792 │ input_layer_3[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
from tensorflow.keras import layers, Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import os
from sklearn.model_selection import train_test_split
# Creating path of folder for segmentation data
dataset_root_folder = 'Human-Segmentation-Dataset'
img_folder = os.path.join(dataset_root_folder, 'Training_Images')
mask_folder = os.path.join(dataset_root_folder, 'Ground_Truth')

print("Loading images and masks")
# Sort files to ensure images align with their correct masks
img_files = sorted(os.listdir(img_folder))
mask_files = sorted(os.listdir(mask_folder))

images = []
masks = []

for img_file, mask_file in zip(img_files, mask_files):
    try:
        # Read Image
        img_path = os.path.join(img_folder, img_file)
        img = cv2.imread(img_path)
        img = cv2.resize(img, (128, 128))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        # Read Mask
        mask_path = os.path.join(mask_folder, mask_file)
        mask = cv2.imread(mask_path, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (128, 128))

        # Normalize
        images.append(img / 255.0)
        masks.append(np.expand_dims(mask, axis=-1) / 255.0)
    except Exception as e:
        print(f"Skipping file: {e}")

images = np.array(images)
masks = np.array(masks)
print(f"Data Loaded. Images: {images.shape}, Masks: {masks.shape}")

#                       Define U-Net Model
def unet(input_size=(128, 128, 3)):
    inputs = layers.Input(input_size)
    # Encoder
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2,2))(c1)

    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2,2))(c2)

    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2,2))(c3)

    # Bottleneck
    c4 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3,3), activation='relu', padding='same')(c4)

    # Decoder
    u1 = layers.UpSampling2D((2,2))(c4)
    u1 = layers.concatenate([u1, c3])
    c5 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(u1)
    c5 = layers.Conv2D(256, (3,3), activation='relu', padding='same')(c5)

    u2 = layers.UpSampling2D((2,2))(c5)
    u2 = layers.concatenate([u2, c2])
    c6 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(u2)
    c6 = layers.Conv2D(128, (3,3), activation='relu', padding='same')(c6)

    u3 = layers.UpSampling2D((2,2))(c6)
    u3 = layers.concatenate([u3, c1])
    c7 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(u3)
    c7 = layers.Conv2D(64, (3,3), activation='relu', padding='same')(c7)

    outputs = layers.Conv2D(1, (1,1), activation='sigmoid')(c7)

    return Model(inputs, outputs)

# Build the model
model = unet()
model.compile(optimizer=Adam(learning_rate=1e-5), loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

#                             Train the model
# Split data into training and validation sets
# Note: Ensure you have at least 81 images loaded for this split to work
train_images, val_images = images[:80], images[80:]
train_masks, val_masks = masks[:80], masks[80:]

# Train the U-Net model
history = model.fit(
    train_images, train_masks,
    validation_data=(val_images, val_masks),
    batch_size=8,
    epochs=20
)

#                            Evaluate & Visualize Results
# Evaluate the model on validation data
loss, accuracy = model.evaluate(val_images, val_masks)
print(f"Validation Loss: {loss}, Validation Accuracy: {accuracy}")

#                            Visualization
# Predict on a few validation samples
pred_masks = model.predict(val_images)

# Plot the results
def plot_sample(image, true_mask, pred_mask):
    plt.figure(figsize=(10,4))

    plt.subplot(1,3,1)
    plt.title('Input Image')
    plt.imshow(image)

    plt.subplot(1,3,2)
    plt.title('True Mask')
    plt.imshow(true_mask.squeeze(), cmap='gray')

    plt.subplot(1,3,3)
    plt.title('Predicted Mask')
    plt.imshow((pred_mask.squeeze() > 0.5).astype(np.uint8),cmap='gray')

# show a sample result
for i in range(3):
    # Check to make sure we actually have validation images to show
    if i < len(val_images):
        plot_sample(val_images[i], val_masks[i], pred_masks[i])
        plt.show()
# Out:
# Loading images and masks
# Skipping file: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/resize.cpp:4208: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# Data Loaded. Images: (290, 128, 128, 3), Masks: (290, 128, 128, 1)
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 128, 128,  │      1,792 │ input_layer_4[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...
